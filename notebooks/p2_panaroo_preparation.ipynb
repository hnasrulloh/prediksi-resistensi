# %% [markdown]
# # Panaroo Preparation

# %%
pwd()
# Out:
# '/home/hnasrulloh/Works/pangenomes/notebooks'

# %%
from os import path
from collections import defaultdict

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats

# %%
DATA_DIR = path.join(path.pardir, 'data')

SAMPLES_DIR = path.join(DATA_DIR, 'samples')
QC_DIR = path.join(DATA_DIR, 'qc')

# %%
NGENES_TXT = path.join(QC_DIR, 'ngenes.txt')

genes = pd.read_csv(NGENES_TXT, sep='\t', dtype={'sample': str, 'no_genes': np.float64})
genes.columns = ['genome_id', 'total_genes']
genes
# Out:
#      genome_id  total_genes
# 0    1267355.3       4365.0
# 1    1267356.3       4345.0
# 2    1267358.3       4358.0
# 3    1267359.3       4331.0
# 4    1267361.3       4359.0
# ..         ...          ...
# 506   1773.203       4312.0
# 507   1773.204       4269.0
# 508   652616.4       4372.0
# 509   83331.31       4346.0
# 510   83332.12       4367.0
#
# [511 rows x 2 columns]

# %%
upper_outlier = genes[genes['genome_id'] == '1402602.3'].total_genes.to_list()[0]
lower_outlier = genes[genes['genome_id'] == '1773.201'].total_genes.to_list()[0]

genes = genes[(genes.total_genes <= upper_outlier) & (genes.total_genes >= lower_outlier)]
genes
# Out:
#      genome_id  total_genes
# 0    1267355.3       4365.0
# 1    1267356.3       4345.0
# 2    1267358.3       4358.0
# 3    1267359.3       4331.0
# 4    1267361.3       4359.0
# ..         ...          ...
# 505   1773.202       4307.0
# 506   1773.203       4312.0
# 508   652616.4       4372.0
# 509   83331.31       4346.0
# 510   83332.12       4367.0
#
# [485 rows x 2 columns]

# %%
mds_outliers = ['1324246.3']

genes = genes[~genes.genome_id.isin(mds_outliers)]
genes
# Out:
#      genome_id  total_genes
# 0    1267355.3       4365.0
# 1    1267356.3       4345.0
# 2    1267358.3       4358.0
# 3    1267359.3       4331.0
# 4    1267361.3       4359.0
# ..         ...          ...
# 505   1773.202       4307.0
# 506   1773.203       4312.0
# 508   652616.4       4372.0
# 509   83331.31       4346.0
# 510   83332.12       4367.0
#
# [484 rows x 2 columns]

# %%
AMR_BEFORE_MASH = path.join(DATA_DIR, 'amr_before_mash.xlsx')
df_amr = pd.read_excel(AMR_BEFORE_MASH, dtype=str)

df_amr = df_amr[df_amr.genome_id.isin(genes.genome_id)]

AMR_READY = path.join(DATA_DIR, 'amr_ready.xlsx')
df_amr.to_excel(AMR_READY, index=False)

df_amr
# Out:
#       genome_id                                  genome_name    antibiotic  \
# 0     1438833.3            Mycobacterium tuberculosis 1010SM      rifampin
# 1     1438833.3            Mycobacterium tuberculosis 1010SM  streptomycin
# 2     1438835.3            Mycobacterium tuberculosis 1173CS    ethambutol
# 3     1438835.3            Mycobacterium tuberculosis 1173CS      rifampin
# 4     1438837.3            Mycobacterium tuberculosis 1429BH    ethambutol
# ...         ...                                          ...           ...
# 1226   1773.201  Mycobacterium tuberculosis strain MAL010119     isoniazid
# 1227   1773.201  Mycobacterium tuberculosis strain MAL010119      rifampin
# 1228   1773.201  Mycobacterium tuberculosis strain MAL010119  streptomycin
# 1229   1773.202  Mycobacterium tuberculosis strain MAL020139     isoniazid
# 1230   1773.202  Mycobacterium tuberculosis strain MAL020139  streptomycin
#
#      phenotype measurement measurement_unit laboratory_typing_method
# 0            R          40             mg/L          Agar proportion
# 1            R           4             mg/L          Agar proportion
# 2            S           2             mg/L          Agar proportion
# 3            R          40             mg/L          Agar proportion
# 4            S           2             mg/L          Agar proportion
# ...        ...         ...              ...                      ...
# 1226         S         0.1             mg/L           Broth dilution
# 1227         S         0.1             mg/L           Broth dilution
# 1228         S           2             mg/L            Agar dilution
# 1229         R           1             mg/L            Agar dilution
# 1230         S           2             mg/L            Agar dilution
#
# [1154 rows x 7 columns]

# %%
GENOMES_BEFORE_MASH = path.join(DATA_DIR, 'genomes_before_mash.xlsx')
df_genomes = pd.read_excel(GENOMES_BEFORE_MASH, dtype=str)

df_genomes = df_genomes[df_genomes.genome_id.isin(genes.genome_id)]

GENOMES_READY = path.join(DATA_DIR, 'genomes_ready.xlsx')
df_genomes.to_excel(GENOMES_READY, index=False)

df_genomes
# Out:
#      genome_id                                  genome_name     strain  \
# 0    1438833.3            Mycobacterium tuberculosis 1010SM     1010SM
# 1    1438835.3            Mycobacterium tuberculosis 1173CS     1173CS
# 2    1438837.3            Mycobacterium tuberculosis 1429BH     1429BH
# 3    1438838.3            Mycobacterium tuberculosis 1430BH     1430BH
# 4    1438842.3            Mycobacterium tuberculosis 1755BN     1755BN
# ..         ...                                          ...        ...
# 504   1773.199  Mycobacterium tuberculosis strain MAL010075  MAL010075
# 505   1773.200  Mycobacterium tuberculosis strain MAL010077  MAL010077
# 506   1773.201  Mycobacterium tuberculosis strain MAL010119  MAL010119
# 507   1773.202  Mycobacterium tuberculosis strain MAL020139  MAL020139
# 508   1773.203  Mycobacterium tuberculosis strain MAL020151  MAL020151
#
#     taxon_id genome_length gc_content fine_consistency checkm_completeness  \
# 0    1438833       4406079       65.6             99.3                 100
# 1    1438835       4383014       65.6             99.2                 100
# 2    1438837       4417210       65.6             99.3                 100
# 3    1438838       4418670       65.6             99.3                 100
# 4    1438842       4394400       65.6             99.3                 100
# ..       ...           ...        ...              ...                 ...
# 504     1773       4421633       65.6             99.3                 100
# 505     1773       4421308       65.6             99.3                 100
# 506     1773       4395080       65.6             98.9                 100
# 507     1773       4413724       65.6             99.4                 100
# 508     1773       4396046       65.6             99.3                 100
#
#     checkm_contamination       completion_date  ... sequences patric_cds  \
# 0                      0  2014-04-29T00:00:00Z  ...       NaN       4372
# 1                      0  2014-04-29T00:00:00Z  ...       NaN       4333
# 2                      0  2014-04-29T00:00:00Z  ...       NaN       4384
# 3                      0  2014-04-29T00:00:00Z  ...       NaN       4383
# 4                      0  2014-04-29T00:00:00Z  ...       NaN       4360
# ..                   ...                   ...  ...       ...        ...
# 504                    0  2014-04-29T00:00:00Z  ...       NaN       4320
# 505                    0  2014-04-29T00:00:00Z  ...       NaN       4304
# 506                    0  2014-04-29T00:00:00Z  ...       NaN       4297
# 507                    0  2014-04-29T00:00:00Z  ...       NaN       4307
# 508                    0  2014-04-29T00:00:00Z  ...       NaN       4312
#
#     refseq_cds isolation_site isolation_source isolation_comments  \
# 0         4006            NaN              neg                NaN
# 1         3982            NaN     Bodily fluid                NaN
# 2         4022            NaN     Bodily fluid                NaN
# 3         4023            NaN     Bodily fluid                NaN
# 4         3987            NaN     Bodily fluid                NaN
# ..         ...            ...              ...                ...
# 504       4006            NaN              NaN                NaN
# 505       4006            NaN              NaN                NaN
# 506       3994            NaN              NaN                NaN
# 507       4003            NaN              NaN                NaN
# 508       4019            NaN              NaN                NaN
#
#     collection_date geographic_location            host_name          comments
# 0              2013             Romania  Human, Homo sapiens  TB-ARC - Romania
# 1              2012             Romania  Human, Homo sapiens  TB-ARC - Romania
# 2              2013             Romania  Human, Homo sapiens  TB-ARC - Romania
# 3              2013             Romania  Human, Homo sapiens  TB-ARC - Romania
# 4              2013             Romania  Human, Homo sapiens  TB-ARC - Romania
# ..              ...                 ...                  ...               ...
# 504            2007                Mali  Human, Homo sapiens     TB-ARC - Mali
# 505             NaN                Mali  Human, Homo sapiens     TB-ARC - Mali
# 506            2010                Mali  Human, Homo sapiens     TB-ARC - Mali
# 507            2007                Mali  Human, Homo sapiens     TB-ARC - Mali
# 508            2007                Mali  Human, Homo sapiens     TB-ARC - Mali
#
# [483 rows x 33 columns]

# %% [markdown]
# **REMEBER** to add the genome reference!
# - Genome ID: **83332.12**
# - Genome Name: **Mycobacterium tuberculosis H37Rv**

# %%
PANAROO_READY = path.join(SAMPLES_DIR, '_panaroo_ready.txt')
IDS_READY = path.join(SAMPLES_DIR, '_id_ready.txt')

f_panaroo = open(PANAROO_READY, 'w')
f_id = open(IDS_READY, 'w')

ids = ['83332.12']
ids.extend(genes.genome_id.to_list())
for gid in ids:
    f_panaroo.write(f'{gid}.PATRIC.gff {gid}.fna\n')
    f_id.write(f'{gid}\n')
    
f_panaroo.close()
f_id.close()

# %%
# Plot the distributions
dist = defaultdict(int)
for d in df_amr[['antibiotic', 'phenotype']].itertuples():
    name = f'{d.antibiotic}:{d.phenotype}'
    dist[name] += 1
    
antibiotics = set([a.split(':')[0] for a in dist.keys()])
counts = [(dist[f'{a}:R'], dist[f'{a}:S']) for a in antibiotics]
pd.DataFrame(counts, index=list(antibiotics), columns=['resistant', 'susceptible'])
# Out:
#               resistant  susceptible
# ethambutol           40           97
# isoniazid           235          172
# streptomycin         82          258
# rifampin             82          188
